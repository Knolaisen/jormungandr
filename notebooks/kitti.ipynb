# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in /home/svernys/.local/lib/python3.9/site-packages (8.4.47)
# Requirement already satisfied: numpy>=1.23.0 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (3.9.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (1.36.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/svernys/.local/lib/python3.9/site-packages (from ultralytics) (2.0.19)
# Requirement already satisfied: contourpy>=1.0.1 in /home/svernys/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/svernys/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/svernys/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/svernys/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/svernys/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/svernys/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/svernys/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/svernys/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->ultralytics) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/svernys/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.23.0)
# Requirement already satisfied: polars-runtime-32==1.36.1 in /home/svernys/.local/lib/python3.9/site-packages (from polars>=0.20.0->ultralytics) (1.36.1)
# Requirement already satisfied: six>=1.5 in /home/svernys/.local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/svernys/.local/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/svernys/.local/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/svernys/.local/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/svernys/.local/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (2026.4.22)
# Requirement already satisfied: filelock in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/svernys/.local/lib/python3.9/site-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.9/site-packages (from triton==3.4.0->torch>=1.8.0->ultralytics) (58.1.0)
# Requirement already satisfied: importlib-metadata in /home/svernys/.local/lib/python3.9/site-packages (from triton==3.4.0->torch>=1.8.0->ultralytics) (8.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/svernys/.local/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/svernys/.local/lib/python3.9/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
import os

from PIL import Image
import torch
from torch.utils.data import Dataset
import ultralytics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 import torch
#       5 from torch.utils.data import Dataset
# ----> 6 import ultralytics
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
from ultralytics.data.utils import check_det_dataset
from ultralytics import settings

data = check_det_dataset("kitti.yaml")  # downloads if missing
print(data)
print("Datasets directory:", settings["datasets_dir"])

# %%
class StillImageKITTIDataset(Dataset):
